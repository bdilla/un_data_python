# %% [markdown]
# # UN Data Analysis Project
#
# Analysis on UN Data comparingh gdp per capita and internet usage

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Formatting

# %%
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv', error_bad_lines = False)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  1734.723214              NaN
# 1     Afghanistan  2017  1758.465636              NaN
# 2     Afghanistan  2016  1757.023490              NaN
# 3     Afghanistan  2015  1766.593077              NaN
# 4     Afghanistan  2014  1795.735834              NaN
# 5     Afghanistan  2013  1807.762344              NaN

# %%
internet_df = pd.read_csv('../data/internet_use.csv', error_bad_lines = False)
# Out:
# b'Skipping line 4675: expected 4 fields, saw 6\n'

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
gdp_df.shape
# Out:
# (6731, 4)

# %%
internet_df.shape
# Out:
# (4675, 4)

# %%
print(type(gdp_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                object
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                object
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
gdp_df.tail(10)
# Out:
#      Country or Area                                      Year        Value  \
# 6721        Zimbabwe                                      1997  3036.422224
# 6722        Zimbabwe                                      1996  2985.856605
# 6723        Zimbabwe                                      1995  2736.486436
# 6724        Zimbabwe                                      1994  2768.309953
# 6725        Zimbabwe                                      1993  2572.870395
# 6726        Zimbabwe                                      1992  2591.007534
# 6727        Zimbabwe                                      1991  2906.272849
# 6728        Zimbabwe                                      1990  2819.549467
# 6729   footnoteSeqID                                  Footnote          NaN
# 6730               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6721              NaN
# 6722              NaN
# 6723              NaN
# 6724              NaN
# ...

# %%
internet_df.tail(10)
# Out:
#      Country or Area                                               Year  \
# 4665             170                   Refers to the total population.
# 4666             171                        Internet Dial-up customers.
# 4667             172  Population age 16+ using the Internet in the l...
# 4668             173  Population age 16+ using internet in the last ...
# 4669             174  U.S. Census Bureau, Table 2. Reported Internet...
# 4670             175             Includes individuals 3 years and older
# 4671             176                                   NTIA/CPS survey.
# 4672             178  Estimated based on Survey's results. Populatio...
# 4673             179                     Preliminary. Country estimate.
# 4674             180  The methodology used to estimated the figure f...
#
#       Value  Value Footnotes
# 4665    NaN              NaN
# 4666    NaN              NaN
# 4667    NaN              NaN
# 4668    NaN              NaN
# ...

# %%
del internet_df['Value Footnotes']

# %%
del gdp_df['Value Footnotes']

# %%
gdp_df.head(5)
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  1734.723214
# 1     Afghanistan  2017  1758.465636
# 2     Afghanistan  2016  1757.023490
# 3     Afghanistan  2015  1766.593077
# 4     Afghanistan  2014  1795.735834

# %%
internet_df.head(5)
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %%
gdp_df.columns = ['Country','Year','GDP_Per_Capita']

# %%
gdp_df.head(5)
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     1734.723214
# 1  Afghanistan  2017     1758.465636
# 2  Afghanistan  2016     1757.023490
# 3  Afghanistan  2015     1766.593077
# 4  Afghanistan  2014     1795.735834

# %%
internet_df.columns = ['Country','Year','Internet_Users_Pct']

# %%
internet_df.head(5)
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %%
gdp_and_internet_use = gdp_df.merge(internet_df)

# %%
gdp_and_internet_use.head(5)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2014     1795.735834            6.390000
# 1  Afghanistan  2013     1807.762344            5.900000
# 2  Afghanistan  2012     1772.764974            5.454545
# 3  Afghanistan  2011     1626.764793            5.000000
# 4  Afghanistan  2010     1671.581238            4.000000

# %%
gdp_and_internet_use.tail(5)
# Out:
#             Country      Year  GDP_Per_Capita  Internet_Users_Pct
# 3515       Zimbabwe      1996     2985.856605            0.016790
# 3516       Zimbabwe      1995     2736.486436            0.007684
# 3517       Zimbabwe      1994     2768.309953            0.001739
# 3518       Zimbabwe      1990     2819.549467            0.000000
# 3519  footnoteSeqID  Footnote             NaN                 NaN

# %%
gdp_df.tail(5)
# Out:
#             Country                                      Year  GDP_Per_Capita
# 6726       Zimbabwe                                      1992     2591.007534
# 6727       Zimbabwe                                      1991     2906.272849
# 6728       Zimbabwe                                      1990     2819.549467
# 6729  footnoteSeqID                                  Footnote             NaN
# 6730              2  Excludes South Sudan after July 9, 2011.             NaN

# %%
internet_df.tail(5)
# Out:
#      Country                                               Year  \
# 4670     175             Includes individuals 3 years and older
# 4671     176                                   NTIA/CPS survey.
# 4672     178  Estimated based on Survey's results. Populatio...
# 4673     179                     Preliminary. Country estimate.
# 4674     180  The methodology used to estimated the figure f...
#
#       Internet_Users_Pct
# 4670                 NaN
# 4671                 NaN
# 4672                 NaN
# 4673                 NaN
# 4674                 NaN

# %%
gdp_and_internet_use[gdp_and_internet_use.Year.isin(['2004','2009','2014'])]
#gdp_and
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2014     1795.735834            6.390000
# 5     Afghanistan  2009     1502.354073            3.550000
# 10    Afghanistan  2004     1025.208245            0.105809
# 13        Albania  2014    10700.993216           60.100000
# 18        Albania  2009     9525.377979           41.200000
# ...           ...   ...             ...                 ...
# 3480       Zambia  2009     3115.937579            6.310000
# 3485       Zambia  2004     2415.590117            2.013550
# 3497     Zimbabwe  2014     2506.490220           19.890000
# 3502     Zimbabwe  2009     1632.999866           11.360000
# 3507     Zimbabwe  2004     2104.143512            6.564045
#
# [488 rows x 4 columns]

# %%
gdp_internet_2004 = gdp_and_internet_use[gdp_and_internet_use.Year.isin(['2004'])]
gdp_internet_2009 = gdp_and_internet_use[gdp_and_internet_use.Year.isin(['2009'])]
gdp_internet_2014 = gdp_and_internet_use[gdp_and_internet_use.Year.isin(['2014'])]

# %%
gdp_internet_2004.head()
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10          Afghanistan  2004     1025.208245            0.105809
# 23              Albania  2004     7001.054082            2.420388
# 44              Algeria  2004    11845.170512            4.634475
# 66               Angola  2004     4604.657044            0.464815
# 86  Antigua and Barbuda  2004    21161.123532           24.266544

# %%
gdp_internet_2009.head()
# Out:
#                 Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5           Afghanistan  2009     1502.354073                3.55
# 18              Albania  2009     9525.377979               41.20
# 39              Algeria  2009    12697.690780               11.23
# 61               Angola  2009     6292.534856                6.00
# 81  Antigua and Barbuda  2009    22568.626530               42.00

# %%
gdp_internet_2014.tail()
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3411    Vanuatu  2014     2837.122659               18.80
# 3431  Venezuela  2014    17131.386907               57.00
# 3455      Yemen  2014     3828.484887               22.55
# 3475     Zambia  2014     3684.685507               17.34
# 3497   Zimbabwe  2014     2506.490220               19.89

# %%
gdp_internet_2014.sort_values(by=['Internet_Users_Pct'], ascending=False)
#Iceland 98.16%
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1395      Iceland  2014    42774.888849               98.16
# 2310       Norway  2014    63328.259526               96.30
# 854       Denmark  2014    45057.083449               95.99
# 1812   Luxembourg  2014    92349.186429               94.67
# 2199  Netherlands  2014    46238.209707               93.17
# ...           ...   ...             ...                 ...
# 2136      Myanmar  2014     4737.459861                2.10
# 2270        Niger  2014      900.136918                1.95
# 1275       Guinea  2014     1836.532318                1.72
# 539       Burundi  2014      768.469837                1.38
# 3104  Timor-Leste  2014     6466.737732                1.14
#
# [164 rows x 4 columns]

# %%
gdp_internet_2014.sort_values(by=['Internet_Users_Pct'], ascending=True)
#Timor-Leste 1.14%
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3104   Timor-Leste  2014     6466.737732                1.14
# 539        Burundi  2014      768.469837                1.38
# 1275        Guinea  2014     1836.532318                1.72
# 2270         Niger  2014      900.136918                1.95
# 2742  Sierra Leone  2014     1707.097335                2.10
# ...            ...   ...             ...                 ...
# 2199   Netherlands  2014    46238.209707               93.17
# 1812    Luxembourg  2014    92349.186429               94.67
# 854        Denmark  2014    45057.083449               95.99
# 2310        Norway  2014    63328.259526               96.30
# 1395       Iceland  2014    42774.888849               98.16
#
# [164 rows x 4 columns]

# %%
gdp_internet_2009.sort_values(by=['Internet_Users_Pct'], ascending=False)
#Iceland 93%
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1400       Iceland  2009    41505.084834           93.000000
# 2315        Norway  2009    62617.153609           92.080000
# 2997        Sweden  2009    41327.626252           91.000000
# 2204   Netherlands  2009    45724.862764           89.630000
# 1817    Luxembourg  2009    89098.734264           87.310000
# ...            ...   ...             ...                 ...
# 1028      Ethiopia  2009      981.718208            0.540000
# 569       Cambodia  2009     2417.293669            0.530000
# 2747  Sierra Leone  2009     1172.862734            0.260000
# 2141       Myanmar  2009     3387.818242            0.220000
# 3109   Timor-Leste  2009     9275.529371            0.185252
#
# [165 rows x 4 columns]

# %%
gdp_internet_2009.sort_values(by=['Internet_Users_Pct'], ascending=True)
#Timor-Leste .19%
# Out:
#            Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3109   Timor-Leste  2009     9275.529371            0.185252
# 2141       Myanmar  2009     3387.818242            0.220000
# 2747  Sierra Leone  2009     1172.862734            0.260000
# 569       Cambodia  2009     2417.293669            0.530000
# 988        Eritrea  2009     1950.533339            0.540000
# ...            ...   ...             ...                 ...
# 1817    Luxembourg  2009    89098.734264           87.310000
# 2204   Netherlands  2009    45724.862764           89.630000
# 2997        Sweden  2009    41327.626252           91.000000
# 2315        Norway  2009    62617.153609           92.080000
# 1400       Iceland  2009    41505.084834           93.000000
#
# [165 rows x 4 columns]

# %%
gdp_internet_2004.sort_values(by=['Internet_Users_Pct'], ascending=False)
#Sweden 83.9%
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3002       Sweden  2004    40177.850408           83.890000
# 1405      Iceland  2004    38893.378798           83.880000
# 864       Denmark  2004    43670.446201           80.930000
# 2320       Norway  2004    61612.275634           77.690000
# 1077      Finland  2004    38207.599118           72.390000
# ...           ...   ...             ...                 ...
# 1033     Ethiopia  2004      676.917430            0.155335
# 10    Afghanistan  2004     1025.208245            0.105809
# 3052   Tajikistan  2004     1644.455641            0.077480
# 1773      Liberia  2004      916.487110            0.031011
# 2146      Myanmar  2004     1999.710075            0.024337
#
# [159 rows x 4 columns]

# %%
gdp_internet_2004.sort_values(by=['Internet_Users_Pct'], ascending=True)
#Myanmar .024%
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2146      Myanmar  2004     1999.710075            0.024337
# 1773      Liberia  2004      916.487110            0.031011
# 3052   Tajikistan  2004     1644.455641            0.077480
# 10    Afghanistan  2004     1025.208245            0.105809
# 1033     Ethiopia  2004      676.917430            0.155335
# ...           ...   ...             ...                 ...
# 1077      Finland  2004    38207.599118           72.390000
# 2320       Norway  2004    61612.275634           77.690000
# 864       Denmark  2004    43670.446201           80.930000
# 1405      Iceland  2004    38893.378798           83.880000
# 3002       Sweden  2004    40177.850408           83.890000
#
# [159 rows x 4 columns]

# %%
gdp_internet_2014.sort_values(by=['GDP_Per_Capita'], ascending=False)
#Qatar $116693.51
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2556       Qatar  2014   116693.507701               91.49
# 1812  Luxembourg  2014    92349.186429               94.67
# 2765   Singapore  2014    81965.361071               82.00
# 1685      Kuwait  2014    72588.670676               78.70
# 2310      Norway  2014    63328.259526               96.30
# ...          ...   ...             ...                 ...
# 1765     Liberia  2014     1257.625441                5.41
# 2116  Mozambique  2014     1222.452874                5.94
# 1856      Malawi  2014     1142.530804                5.83
# 2270       Niger  2014      900.136918                1.95
# 539      Burundi  2014      768.469837                1.38
#
# [164 rows x 4 columns]

# %%
gdp_internet_2014.sort_values(by=['GDP_Per_Capita'], ascending=True)
#Burundi
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 539      Burundi  2014      768.469837                1.38
# 2270       Niger  2014      900.136918                1.95
# 1856      Malawi  2014     1142.530804                5.83
# 2116  Mozambique  2014     1222.452874                5.94
# 1765     Liberia  2014     1257.625441                5.41
# ...          ...   ...             ...                 ...
# 2310      Norway  2014    63328.259526               96.30
# 1685      Kuwait  2014    72588.670676               78.70
# 2765   Singapore  2014    81965.361071               82.00
# 1812  Luxembourg  2014    92349.186429               94.67
# 2556       Qatar  2014   116693.507701               91.49
#
# [164 rows x 4 columns]

# %%
plt.scatter(gdp_internet_2004['GDP_Per_Capita'], gdp_internet_2004['Internet_Users_Pct'], c="Blue")
xlab= 'GDP Per Capita'
ylab= 'Internet Users Pct'
title= 'Internet Use by GDP 2004'

plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Internet Use by GDP 2004')

# %%
plt.scatter(gdp_internet_2009['GDP_Per_Capita'], gdp_internet_2009['Internet_Users_Pct'])
xlab= 'GDP Per Capita'
ylab= 'Internet Users Pct'
title= 'Internet Use by GDP 2009'

plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Internet Use by GDP 2009')

# %%
plt.scatter(gdp_internet_2014['GDP_Per_Capita'], gdp_internet_2014['Internet_Users_Pct'])
xlab= 'GDP Per Capita'
ylab= 'Internet Users Pct'
title= 'Internet Use by GDP 2014'

plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Internet Use by GDP 2014')
